# %% [markdown]
# <a href="https://colab.research.google.com/github/rockerritesh/easyOCR_Nepali/blob/main/Nepali_OCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nepali OCR detector.

# %% [markdown]
# ## importing Module

# %%
# !pip install easyocr
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting easyocr
#   Using cached easyocr-1.7.0-py3-none-any.whl (2.9 MB)
# Requirement already satisfied: torch in /home/limsim/.local/lib/python3.11/site-packages (from easyocr) (2.0.1)
# Collecting torchvision>=0.5 (from easyocr)
#   Downloading torchvision-0.15.2-cp311-cp311-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 5.4 MB/s eta 0:00:00m eta 0:00:010:00:010m
# Collecting opencv-python-headless (from easyocr)
#   Using cached opencv_python_headless-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.2 MB)
# Requirement already satisfied: scipy in /home/limsim/.local/lib/python3.11/site-packages (from easyocr) (1.10.1)
# Requirement already satisfied: numpy in /home/limsim/.local/lib/python3.11/site-packages (from easyocr) (1.24.3)
# Requirement already satisfied: Pillow in /usr/lib/python3.11/site-packages (from easyocr) (9.5.0)
# Collecting scikit-image (from easyocr)
#   Downloading scikit_image-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 8.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting python-bidi (from easyocr)
#   Using cached python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: PyYAML in /usr/lib/python3.11/site-packages (from easyocr) (6.0)
# Collecting Shapely (from easyocr)
#   Downloading shapely-2.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 8.2 MB/s eta 0:00:00m eta 0:00:010:01m:01
# Collecting pyclipper (from easyocr)
#   Downloading pyclipper-1.3.0.post4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (869 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.4/869.4 kB 10.1 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting ninja (from easyocr)
#   Using cached ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
# Requirement already satisfied: requests in /home/limsim/.local/lib/python3.11/site-packages (from torchvision>=0.5->easyocr) (2.27.1)
# Requirement already satisfied: filelock in /home/limsim/.local/lib/python3.11/site-packages (from torch->easyocr) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/lib/python3.11/site-packages (from torch->easyocr) (4.5.0)
# Requirement already satisfied: sympy in /home/limsim/.local/lib/python3.11/site-packages (from torch->easyocr) (1.12)
# Requirement already satisfied: networkx in /home/limsim/.local/lib/python3.11/site-packages (from torch->easyocr) (3.1)
# Requirement already satisfied: jinja2 in /usr/lib/python3.11/site-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/limsim/.local/lib/python3.11/site-packages (from torch->easyocr) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/limsim/.local/lib/python3.11/site-packages (from torch->easyocr) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/limsim/.local/lib/python3.11/site-packages (from torch->easyocr) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/limsim/.local/lib/python3.11/site-packages (from torch->easyocr) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/limsim/.local/lib/python3.11/site-packages (from torch->easyocr) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/limsim/.local/lib/python3.11/site-packages (from torch->easyocr) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/limsim/.local/lib/python3.11/site-packages (from torch->easyocr) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/limsim/.local/lib/python3.11/site-packages (from torch->easyocr) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/limsim/.local/lib/python3.11/site-packages (from torch->easyocr) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/limsim/.local/lib/python3.11/site-packages (from torch->easyocr) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/limsim/.local/lib/python3.11/site-packages (from torch->easyocr) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/limsim/.local/lib/python3.11/site-packages (from torch->easyocr) (2.0.0)
# Requirement already satisfied: setuptools in /usr/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->easyocr) (67.7.0)
# Requirement already satisfied: wheel in /usr/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->easyocr) (0.40.0)
# Requirement already satisfied: cmake in /home/limsim/.local/lib/python3.11/site-packages (from triton==2.0.0->torch->easyocr) (3.26.4)
# Requirement already satisfied: lit in /usr/lib/python3.11/site-packages (from triton==2.0.0->torch->easyocr) (15.0.7.dev0)
# Requirement already satisfied: six in /usr/lib/python3.11/site-packages (from python-bidi->easyocr) (1.16.0)
# Collecting imageio>=2.27 (from scikit-image->easyocr)
#   Downloading imageio-2.31.1-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 12.2 MB/s eta 0:00:00
# Collecting tifffile>=2022.8.12 (from scikit-image->easyocr)
#   Downloading tifffile-2023.4.12-py3-none-any.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.4/219.4 kB 17.9 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1 (from scikit-image->easyocr)
#   Downloading PyWavelets-1.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 8.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: packaging>=21 in /usr/lib/python3.11/site-packages (from scikit-image->easyocr) (23.1)
# Collecting lazy_loader>=0.2 (from scikit-image->easyocr)
#   Using cached lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3.11/site-packages (from jinja2->torch->easyocr) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3.11/site-packages (from requests->torchvision>=0.5->easyocr) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3.11/site-packages (from requests->torchvision>=0.5->easyocr) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/limsim/.local/lib/python3.11/site-packages (from requests->torchvision>=0.5->easyocr) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.11/site-packages (from requests->torchvision>=0.5->easyocr) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /home/limsim/.local/lib/python3.11/site-packages (from sympy->torch->easyocr) (1.3.0)
# Requirement already satisfied: platformdirs in /usr/lib/python3.11/site-packages (from setuptools->nvidia-cublas-cu11==11.10.3.66->torch->easyocr) (3.5.1)
# Requirement already satisfied: jaraco.text in /usr/lib/python3.11/site-packages (from setuptools->nvidia-cublas-cu11==11.10.3.66->torch->easyocr) (3.11.1)
# Requirement already satisfied: more-itertools in /usr/lib/python3.11/site-packages (from setuptools->nvidia-cublas-cu11==11.10.3.66->torch->easyocr) (9.1.0)
# Requirement already satisfied: ordered-set in /usr/lib/python3.11/site-packages (from setuptools->nvidia-cublas-cu11==11.10.3.66->torch->easyocr) (4.1.0)
# Requirement already satisfied: tomli in /usr/lib/python3.11/site-packages (from setuptools->nvidia-cublas-cu11==11.10.3.66->torch->easyocr) (2.0.1)
# Requirement already satisfied: validate-pyproject in /usr/lib/python3.11/site-packages (from setuptools->nvidia-cublas-cu11==11.10.3.66->torch->easyocr) (0.12.2.post1.dev0+g2940279.d20230508)
# Requirement already satisfied: jaraco.functools in /usr/lib/python3.11/site-packages (from jaraco.text->setuptools->nvidia-cublas-cu11==11.10.3.66->torch->easyocr) (3.6.0)
# Requirement already satisfied: jaraco.context>=4.1 in /usr/lib/python3.11/site-packages (from jaraco.text->setuptools->nvidia-cublas-cu11==11.10.3.66->torch->easyocr) (4.3.0)
# Requirement already satisfied: autocommand in /usr/lib/python3.11/site-packages (from jaraco.text->setuptools->nvidia-cublas-cu11==11.10.3.66->torch->easyocr) (2.2.2)
# Requirement already satisfied: inflect in /usr/lib/python3.11/site-packages (from jaraco.text->setuptools->nvidia-cublas-cu11==11.10.3.66->torch->easyocr) (6.0.4)
# Requirement already satisfied: fastjsonschema<=3,>=2.16.2 in /usr/lib/python3.11/site-packages (from validate-pyproject->setuptools->nvidia-cublas-cu11==11.10.3.66->torch->easyocr) (2.16.3)
# Requirement already satisfied: pydantic>=1.9.1 in /usr/lib/python3.11/site-packages (from inflect->jaraco.text->setuptools->nvidia-cublas-cu11==11.10.3.66->torch->easyocr) (1.10.7)
# Installing collected packages: pyclipper, ninja, tifffile, Shapely, PyWavelets, python-bidi, opencv-python-headless, lazy_loader, imageio, scikit-image, torchvision, easyocr
# Successfully installed PyWavelets-1.4.1 Shapely-2.0.1 easyocr-1.7.0 imageio-2.31.1 lazy_loader-0.2 ninja-1.11.1 opencv-python-headless-4.7.0.72 pyclipper-1.3.0.post4 python-bidi-0.4.2 scikit-image-0.21.0 tifffile-2023.4.12 torchvision-0.15.2

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
import numpy as np
from pylab import rcParams
from IPython.display import Image
rcParams['figure.figsize'] = 8, 16
# Out:
# /home/limsim/.local/lib/python3.11/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.15) or chardet (5.1.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %% [markdown]
# ## Loading pre trained model.
#
# 'ne' for Nepali and 'en' for english and simillary for other

# %%
reader = easyocr.Reader(['hi']) #'ne' for Nepali and 'en' for english and simillary for other
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %% [markdown]
# ## Normal image to Scaned image

# %%
def map(x, in_min, in_max, out_min, out_max):
    return (x - in_min) * (out_max - out_min) / (in_max - in_min) + out_min

def highPassFilter(img,kSize):
    if not kSize%2:
        kSize +=1
    kernel = np.ones((kSize,kSize),np.float32)/(kSize*kSize)
    filtered = cv2.filter2D(img,-1,kernel)
    filtered = img.astype('float32') - filtered.astype('float32')
    filtered = filtered + 127*np.ones(img.shape, np.uint8)
    filtered = filtered.astype('uint8')
    return filtered

def blackPointSelect(img, blackPoint):
    img = img.astype('int32')
    img = map(img, blackPoint, 255, 0, 255)
    _, img = cv2.threshold(img, 0, 255, cv2.THRESH_TOZERO)
    img = img.astype('uint8')
    return img

def whitePointSelect(img,whitePoint):
    _,img = cv2.threshold(img, whitePoint, 255, cv2.THRESH_TRUNC)
    img = img.astype('int32')
    img = map(img, 0, whitePoint, 0, 255)
    img = img.astype('uint8')
    return img

def blackAndWhite(img):
    lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    (l,a,b) = cv2.split(lab)
    img = cv2.add( cv2.subtract(l,b), cv2.subtract(l,a) )
    return img
def scan_effect(img):
    
    blackPoint = 66
    whitePoint = 130
    image = highPassFilter(img,kSize = 51)
    image_white = whitePointSelect(image, whitePoint)
    img_black = blackPointSelect(image_white, blackPoint)
    image=blackPointSelect(img,blackPoint)
    white = whitePointSelect(image,whitePoint)
    img_black = blackAndWhite(white)
    return img_black

# %% [markdown]
# > Enter the location of image file

# %%
loc="/home/limsim/Desktop/maithili_book/2023-06-23_09-38.png"

# %%
Image(loc)

# %%
img = cv2.imread(loc)
image = scan_effect(img)
#from google.colab.patches import cv2_imshow
#cv2_imshow(image)
filename = 'scanned.jpg'
cv2.imwrite(filename, image)
# Out:
# True

# %% [markdown]
# ## Loading Image

# %%
path=filename

# %%
Image(path)

# %% [markdown]
# ## Detecting character from image

# %%
output = reader.readtext(path)

# %% [markdown]
# ## Output

# %%
output

# %% [markdown]
# ## Total detection

# %%
print(f'Total number of detection',len(output))
# Out:
# Total number of detection 27

# %% [markdown]
# ## Previewing Output

# %%
image = cv2.imread(path)
for i in range(len(output)):
  cord = output[i][0]
  x_min, y_min = [int(min(idx)) for idx in zip(*cord)]
  x_max, y_max = [int(max(idx)) for idx in zip(*cord)]
  cv2.rectangle(image,(x_min,y_min),(x_max,y_max),(0,0,255),2)
  print(output[i][1])

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
# Out:
# त्या बांच्न के ढुकुर झैं नभमा डुलेर
# त्यो मर्नु के कुकुर
# झैं पथमा ढलेर
# त्याे जित्न के मनपरि दुनिया ठगेर
# बांचौं पवित्र जलको सरिता बनरे ।
# गर्दै कि बुद्घ जसरी सबको भलाइ
# वा ज्ञानले
# दुनियां जिगाई
# वा कृष्ण झैं जगत्मा रमिता चलाई
# वा
# विश्वमाझ सबमा ममता फिजाई
# सग्लो र
# पूर्ण सपना मनभित्र सांचौं
# छोटो छ है समयमै भरपुर बांचौं
# हांस्ने गरोस् मन सध्रै दुनियां भुलेर
# डाहा गरोस् जनता नै रिसमा जलेर ।
# सत्कर्मले जगत्को शिरमा पुगिन्छ
# हदयका सब दाग बिल्छ
# आर्दश जीवन सधैं अति पूज्य हुन्छ
# सत्कर्म सन्ततिहरू सबमा फिजिन्छ ।।।
# जो रम्छ व्यर्थपनमा
# त्यसमै सकिन्छन्
# जो बुझछ जीवन उनी इतिहास बन्छन्
# झक्नेछ ईश्वर पनि उसको अगाडि
# जो बांच्छ स्वच्छ दिलले सबलाई बांडी ।०
# जनकभैं
# मुस्कानले
